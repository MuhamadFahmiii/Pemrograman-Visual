# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamadFahmiii/Pemrograman-Visual/blob/main/TM4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan 4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the x-axis values
x = np.linspace(-8, 8, 10000)

# Define the figure size
plt.figure(figsize=(8, 6.5))

# Define the mathematical functions
y = x - x  # y = 0
y1 = (4 - x ** 2) ** 0.5
y2 = -(4 - x ** 2) ** 0.5
y3 = 5 + (4 - (x - 5) ** 2) ** 0.5
y4 = 5 - (4 - (x - 5) ** 2) ** 0.5
y5 = -5 + (4 - (x - 5) ** 2) ** 0.5
y6 = -5 - (4 - (x - 5) ** 2) ** 0.5
y7 = 5 + (4 - (x + 5) ** 2) ** 0.5
y8 = 5 - (4 - (x + 5) ** 2) ** 0.5
y9 = -5 + (4 - (x + 5) ** 2) ** 0.5
y10 = -5 - (4 - (x + 5) ** 2) ** 0.5

# Plot the functions
plt.plot(x, y, 'k')
plt.plot(x, y1, '-r', label='y1, y2')
plt.plot(x, y2, '-r')
plt.plot(x, y3, '-g', label='y3, y4')
plt.plot(x, y4, '-g')
plt.plot(x, y5, '-b', label='y5, y6')
plt.plot(x, y6, 'b')
plt.plot(x, y7, '-y', label='y7, y8')
plt.plot(x, y8, '-y')
plt.plot(x, y9, '-y', label='y9, y10')
plt.plot(x, y10, '-y')

# Add legend and grid
plt.legend(loc='upper center')
plt.grid()

# Display the plot
plt.show()
# Out:
# <ipython-input-3-d86795f87358>:12: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (4 - x ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:13: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(4 - x ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:14: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 5 + (4 - (x - 5) ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:15: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 5 - (4 - (x - 5) ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:16: RuntimeWarning: invalid value encountered in sqrt
#   y5 = -5 + (4 - (x - 5) ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:17: RuntimeWarning: invalid value encountered in sqrt
#   y6 = -5 - (4 - (x - 5) ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:18: RuntimeWarning: invalid value encountered in sqrt
#   y7 = 5 + (4 - (x + 5) ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:19: RuntimeWarning: invalid value encountered in sqrt
#   y8 = 5 - (4 - (x + 5) ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:20: RuntimeWarning: invalid value encountered in sqrt
#   y9 = -5 + (4 - (x + 5) ** 2) ** 0.5
# <ipython-input-3-d86795f87358>:21: RuntimeWarning: invalid value encountered in sqrt
#   y10 = -5 - (4 - (x + 5) ** 2) ** 0.5

# %%
import numpy as np
import matplotlib.pyplot as plt

print("\033c")

# Define x values
x = np.linspace(-4, 4, 10000)

# Create a figure with an aspect ratio of 3:30
plt.figure(figsize=(3, 30))

# Plot a small circle at (0,0)
plt.plot(x, (0.01 - x ** 2) ** 0.5, '-k')
plt.plot(x, -((0.01 - x ** 2) ** 0.5), 'k')

# Define the mathematical functions
y = x - x - 0
y1 = x**3 - 2*x**2 - 5*x + 6

# Plot the functions
plt.plot(x, y, '-k')
plt.plot(x, y1, '-r', label='y1')

# Add legend
plt.legend(loc='upper left')

# Add grid
plt.grid()

# Display the plot
plt.show()

print("\033c")
# Out:
# c
# <ipython-input-4-8566c836b4e5>:13: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01 - x ** 2) ** 0.5, '-k')
# <ipython-input-4-8566c836b4e5>:14: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -((0.01 - x ** 2) ** 0.5), 'k')
# c

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-8,7,100000)
plt.figure(figsize=(9,5.5))

#Tentukan persamaan matematika yang diinginkan
y = x -x -0
y1 = (18-x**2)**0.5
y2 = -(18-x**2)**0.5

y3 = 4 + (4-(x-4)**2)**0.5
y4 = 4 - (4-(x-4)**2)**0.5

y5 = 4 + (4-(x+4)**2)**0.5
y6 = 4 - (4-(x+4)**2)**0.5

plt.plot(x, y, '-k')
plt.plot(x, y1, '-k', label='y1, y2')
plt.plot(x, y2, '-k')
plt.plot(x, y3, '-k', label='y3, y4')
plt.plot(x, y4, '-k')
plt.plot(x, y5, '-k', label='y5, y6')
plt.plot(x, y6, '-k')
plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# <ipython-input-5-4896cf3ec6f8>:10: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (18-x**2)**0.5
# <ipython-input-5-4896cf3ec6f8>:11: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(18-x**2)**0.5
# <ipython-input-5-4896cf3ec6f8>:13: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 4 + (4-(x-4)**2)**0.5
# <ipython-input-5-4896cf3ec6f8>:14: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 4 - (4-(x-4)**2)**0.5
# <ipython-input-5-4896cf3ec6f8>:16: RuntimeWarning: invalid value encountered in sqrt
#   y5 = 4 + (4-(x+4)**2)**0.5
# <ipython-input-5-4896cf3ec6f8>:17: RuntimeWarning: invalid value encountered in sqrt
#   y6 = 4 - (4-(x+4)**2)**0.5

# %%
import numpy as np
import matplotlib.pyplot as plt

print("\033c")

x = np.linspace(-4, 3, 10000)
plt.figure(figsize=(3, 30))

plt.plot(x, -(0.01 - x ** 2) ** 0.5, '-k')
plt.plot(x, (0.01 - x ** 2) ** 0.5, 'k')

y = x - x - 0
y1 = (x ** 3 - 2 * x ** 2 - x + 2)

plt.plot(x, -y, '-k')
plt.plot(x, -y1, '-r', label='y1')

plt.legend(loc='upper left')
plt.grid()
plt.show()
# Out:
# c
# <ipython-input-16-22fb7babc118>:9: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -(0.01 - x ** 2) ** 0.5, '-k')
# <ipython-input-16-22fb7babc118>:10: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01 - x ** 2) ** 0.5, 'k')
